# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_rows = 60

# %%
pd.set_option('display.max_rows', None)

# %%
xbet_all = pd.read_csv('./1xbet_all.csv')
xbet_all
# Out:
#                 Name               Team  Age    Position  Apps  Mins  Goals  \
# 0        Eden Hazard            Chelsea   32     Forward    38  3379     14
# 1     Alexis Sanchez            Arsenal   34     Forward    35  2953     16
# 2      Sergio Aguero           Man City   35     Forward    33  2540     26
# 3      Cesc Fabregas            Chelsea   36  Midfielder    34  2890      3
# 4      Santi Cazorla            Arsenal   38  Midfielder    37  2992      7
# ...              ...                ...  ...         ...   ...   ...    ...
# 4751      Chris Wood  Nottingham Forest   31     Forward    25   816      3
# 4752      Danny Ings        Aston Villa   31     Forward    35  1590      8
# 4753    Daniel James              Leeds   25  Midfielder    24   813      2
# 4754    Craig Dawson             Wolves   33    Defender    25  2137      1
# 4755   Wesley Fofana          Leicester   22    Defender    17  1367      1
#
# ...

# %%
understat_all = pd.read_csv('./understat_all0.csv')
understat_all
# Out:
#          No               Name                 Team  Apps   Min   G  NPG  A  \
# 0       619      Sergio Aguero      Manchester City    33  2551  26   21  8
# 1       647         Harry Kane            Tottenham    34  2589  21   19  4
# 2       802        Diego Costa              Chelsea    26  2111  20   19  3
# 3       848     Charlie Austin  Queens Park Rangers    35  3078  18   15  5
# 4       498     Alexis Sanchez              Arsenal    35  2967  16   16  8
# ...     ...                ...                  ...   ...   ...  ..  ... ..
# 4750  11544    Cameron Peupion             Brighton     1     1   0    0  0
# 4751  11582       Kamari Doyle          Southampton     1     1   0    0  0
# 4752  11583    Dominic Ballard          Southampton     2    17   0    0  0
# 4753  11594       Shea Charles      Manchester City     1    26   0    0  0
# 4754  11618  Samuel Amo-Ameyaw          Southampton     1     1   0    0  0
#
# ...

# %%
capology_all = pd.read_csv('./capology_all0.csv')
capology_all
# Out:
#                   Name  Weekly Salary  Base Salary  ADJ Salary  \
# 0       Radamel Falcao         285000     14820000    17852178
# 1       Angel Di Maria         250000     13000000    15659805
# 2         Wayne Rooney         235000     12220000    14720217
# 3     Robin van Persie         210000     10920000    13154236
# 4           Yaya Toure         190000      9880000    11901452
# ...                ...            ...          ...         ...
# 6135       Cody Drameh           2500       130000      130000
# 6136       Will Dennis           2000       104000      104000
# 6137        Leo Hjelde           2000       104000      104000
# 6138       Darko Gyabi              0            0           0
# 6139   Sergio Reguilon              0            0           0
#
#                    Team  year
# 0     Manchester United  2014
# 1     Manchester United  2014
# 2     Manchester United  2014
# 3     Manchester United  2014
# 4       Manchester City  2014
# ...

# %%
con_all = pd.merge(capology_all,xbet_all , on = ['Name','year'] )
con_all
# Out:
#                   Name  Weekly Salary  Base Salary  ADJ Salary  \
# 0       Radamel Falcao         285000     14820000    17852178
# 1       Angel Di Maria         250000     13000000    15659805
# 2         Wayne Rooney         235000     12220000    14720217
# 3     Robin van Persie         210000     10920000    13154236
# 4           Yaya Toure         190000      9880000    11901452
# ...                ...            ...          ...         ...
# 4741      Alex Mighten           3462       180000      180000
# 4742      Connor Ronan           3000       156000      156000
# 4743     Chem Campbell           2500       130000      130000
# 4744       Cody Drameh           2500       130000      130000
# 4745       Darko Gyabi              0            0           0
#
#                  Team_x  year             Team_y  Age    Position  Apps  ...  \
# 0     Manchester United  2014            Man Utd   37     Forward    26  ...
# ...

# %%
con_all.loc[con_all['Name']== 'Sergio Aguero']
# Out:
#                Name  Weekly Salary  Base Salary  ADJ Salary           Team_x  \
# 10    Sergio Aguero         160000      8320000    10022275  Manchester City
# 568   Sergio Aguero         160000      8320000     9922218  Manchester City
# 1135  Sergio Aguero         160000      8320000     9674761  Manchester City
# 1703  Sergio Aguero         160000      8320000     9457906  Manchester City
# 2224  Sergio Aguero         230135     11967000    13371291  Manchester City
# 2742  Sergio Aguero         230192     11970000    13243599  Manchester City
# 3226  Sergio Aguero         230192     11970000    12918269  Manchester City
#
#       year    Team_y  Age Position  Apps  ...    Rating   Tackles     Inter  \
# 10    2014  Man City   35  Forward    33  ...  7.671515  0.666667  0.393939
# 568   2015  Man City   35  Forward    30  ...  7.385333  0.500000  0.200000
# 1135  2016  Man City   35  Forward    31  ...  7.333548  0.580645  0.096774
# ...

# %%
data = con_all
data = data.dropna() # 결측치 모두 제거.
data.info
# Out:
# <bound method DataFrame.info of                   Name  Weekly Salary  Base Salary  ADJ Salary  \
# 0       Radamel Falcao         285000     14820000    17852178
# 1       Angel Di Maria         250000     13000000    15659805
# 2         Wayne Rooney         235000     12220000    14720217
# 3     Robin van Persie         210000     10920000    13154236
# 4           Yaya Toure         190000      9880000    11901452
# ...                ...            ...          ...         ...
# 4741      Alex Mighten           3462       180000      180000
# 4742      Connor Ronan           3000       156000      156000
# 4743     Chem Campbell           2500       130000      130000
# 4744       Cody Drameh           2500       130000      130000
# 4745       Darko Gyabi              0            0           0
#
#                  Team_x  year             Team_y  Age    Position  Apps  ...  \
# 0     Manchester United  2014            Man Utd   37     Forward    26  ...
# ...

# %%
sns.scatterplot(data=data, x='Apps', y='Weekly Salary',s=15)
# Out:
# <Axes: xlabel='Apps', ylabel='Weekly Salary'>

# %%
con_all
# Out:
#                   Name  Weekly Salary  Base Salary  ADJ Salary  \
# 0       Radamel Falcao         285000     14820000    17852178
# 1       Angel Di Maria         250000     13000000    15659805
# 2         Wayne Rooney         235000     12220000    14720217
# 3     Robin van Persie         210000     10920000    13154236
# 4           Yaya Toure         190000      9880000    11901452
# ...                ...            ...          ...         ...
# 4741      Alex Mighten           3462       180000      180000
# 4742      Connor Ronan           3000       156000      156000
# 4743     Chem Campbell           2500       130000      130000
# 4744       Cody Drameh           2500       130000      130000
# 4745       Darko Gyabi              0            0           0
#
#                  Team_x  year             Team_y  Age    Position  Apps  ...  \
# 0     Manchester United  2014            Man Utd   37     Forward    26  ...
# ...

# %%
player_df = pd.read_csv('./players_all.csv')
player_df = player_df.rename(columns={'Unnamed: 0':'Id'})
player_df
# Out:
#         Id   No.  year              Name  Age         Team    Position
# 0        0   450  2014       Eden Hazard   23      Chelsea     Forward
# 1        1    74  2014    Alexis Sanchez   25      Arsenal     Forward
# 2        2  1508  2014     Sergio Aguero   26     Man City     Forward
# 3        3   261  2014     Cesc Fabregas   27      Chelsea  Midfielder
# 4        4  1480  2014     Santi Cazorla   29      Arsenal  Midfielder
# ...    ...   ...   ...               ...  ...          ...         ...
# 4751  4751   411  2022  Dexter Lembikisa   18       Wolves    Defender
# 4752  4752   247  2022   Cameron Peupion   19     Brighton  Midfielder
# 4753  4753   110  2022      Andrew Moran   18     Brighton  Midfielder
# 4754  4754  1515  2022       Shane Duffy   30       Fulham    Defender
# 4755  4755  1713  2022        Yan Valery   23  Southampton    Defender
#
# [4756 rows x 7 columns]

# %%
con_all.corr()
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_6616\362727715.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   con_all.corr()
#                Weekly Salary  Base Salary  ADJ Salary      year       Age  \
# Weekly Salary       1.000000     1.000000    0.995760  0.222187  0.074247
# Base Salary         1.000000     1.000000    0.995760  0.222187  0.074247
# ADJ Salary          0.995760     0.995760    1.000000  0.162239  0.109961
# year                0.222187     0.222187    0.162239  1.000000 -0.520026
# Age                 0.074247     0.074247    0.109961 -0.520026  1.000000
# Apps                0.293747     0.293746    0.300180  0.068900  0.078453
# Mins                0.272074     0.272074    0.279267  0.037938  0.119464
# Goals               0.368723     0.368723    0.376519  0.026778 -0.010591
# ...

# %%
plt.figure(figsize=(7, 6))
sns.heatmap(data=data.corr(), annot=False, fmt='.3f',cmap='Blues')
plt.show()
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_6616\1506648359.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=data.corr(), annot=False, fmt='.3f',cmap='Blues')

# %%
con_df1 = con_all[con_all['Mins']>1400]
con_df1[con_df1['Age']>35]
# Out:
#                   Name  Weekly Salary  Base Salary  ADJ Salary  \
# 2         Wayne Rooney         235000     12220000    14720217
# 3     Robin van Persie         210000     10920000    13154236
# 4           Yaya Toure         190000      9880000    11901452
# 6           John Terry         175000      9100000    10961863
# 7        Cesc Fabregas         171481      8917000    10741422
# ...                ...            ...          ...         ...
# 4327       Hugo Lloris         100000      5200000     5200000
# 4346      Keylor Navas          90000      4680000     4680000
# 4397    Vicente Guaita          75000      3900000     3900000
# 4420  Lukasz Fabianski          65000      3380000     3380000
# 4483      Ashley Young          50000      2600000     2600000
#
#                  Team_x  year             Team_y  Age    Position  Apps  ...  \
# 2     Manchester United  2014            Man Utd   37     Forward    33  ...
# ...
